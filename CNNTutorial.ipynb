# %% [markdown]
# # CNN Tutorial
#
# Sources used:
# * https://stanford.edu/~shervine/teaching/cs-230/cheatsheet-convolutional-neural-networks
# * https://cs231n.github.io/convolutional-networks/
# * https://www.datacamp.com/tutorial/convolutional-neural-networks-python

# %% [markdown]
# ## Notes:
#
# * CNN has three layers:
#     * Convolution: uses filters to scan input and output feature map/activation map
#     * Pooling: takes either the maximum value or average value of features (maximum pooling is more common)
#     * Fully Connected: feature map are inputted to neurons
# * Example structure:
#     * Input [32x32x3]: [width x height x color channels]
#     * CONV [32x32x12]: last value depends on num. of filters, in this example 12 filters
#     * RELU [32x32x12]: activation function, same volume size
#     * POOL [16x16x12]: downsampling along width/height
#     * FC [1x1x10]: compute class cores, num. 1-10 corr. to class score, each neuron is connected to all num. in prev. volume
# * Used in image classification

# %% [markdown]
# ## Implementation:

# %%
# Set up:
from keras.datasets import fashion_mnist
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt
# %matplotlib inline

(train_X,train_Y), (test_X,test_Y) = fashion_mnist.load_data()

print('Training data shape : ', train_X.shape, train_Y.shape)

print('Testing data shape : ', test_X.shape, test_Y.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Set up:
# ----> 2 from keras.datasets import fashion_mnist
#       3 import numpy as np
#       4 from keras.utils import to_categorical
#
# File c:\Users\johna\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\__init__.py:4
#       1 import os
#       3 # DO NOT EDIT. Generated by api_gen.sh
# ----> 4 from keras.api import DTypePolicy
#       5 from keras.api import FloatDTypePolicy
#       6 from keras.api import Function
#
# File c:\Users\johna\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\api\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
# ...
